# %%
import string
import random
import sys # Для вычисления размера обьекта в байтах для 3 задачи

# %% [markdown]
# # Задание 1

# %%
def ten_random_chr(k=10):  # Вводим необязательный аргумент на случай если надо будет выбрать не 10 элементов
    chr_list = list(string.ascii_letters)  # Полчаем строку символов и преобразуем ее в список
    num_list = list(string.digits)
    chr_list.extend(num_list)
    res_list = random.sample(chr_list, k=k)  # Если использовать random.choices то в выборке могут быть повторения
    return res_list


print("Задание №1 - ")
res = ten_random_chr()
print(res)
# Out:
# Задание №1 -
# ['P', '4', 'M', 'E', 'Y', 'Z', 'R', '1', 'v', 'k']

# %% [markdown]
# # Задание 2

# %%
def dict_from_lists(value_list, key_list):
    res = dict()
    if len(value_list) == len(key_list):
        for i in range (len(key_list)): # В цикле каждому элементу списка ключей сопоставляем в словаре значение
            res[key_list[i]] = value_list[i]
    return res
  

print("Задание №2 - ")
print("Введите текст из 10 слов (Или любые символы если нужно использовать текст по умолчанию)")
text = input()
text_list = text.split()  # Разбиваем текст по пробелам в список
if len(text_list) != 10: # Если текст не ввели
    text = "Разбейте произвольный текст на слова и поставьте в соответствие каждому"
    print("\nБудет использован текст - " + text)
    text_list = text.split()
dict_res = dict_from_lists(text_list, res)
print("\nПолученный словарь - ")
print(dict_res)
# Out:
# Задание №2 -
# Введите текст из 10 слов (Или любые символы если нужно использовать текст по умолчанию)
# rg
#
# Будет использован текст - Разбейте произвольный текст на слова и поставьте в соответствие каждому
#
# Полученный словарь -
# {'P': 'Разбейте', '4': 'произвольный', 'M': 'текст', 'E': 'на', 'Y': 'слова', 'Z': 'и', 'R': 'поставьте', '1': 'в', 'v': 'соответствие', 'k': 'каждому'}

# %% [markdown]
# # Задание 3

# %%
def bytes_universal_hash(num, size):
    num = int(num)
    bytes_size = sys.getsizeof(num) # Сколько байт в памяти занимает введенной число
    str_bytes = num.to_bytes(bytes_size, 'big') # Использем big_endian порядок байт (от старшего к меньшему)
    hash = 0 # Будем считать хеш накопительным итогом по методу Горнера
    for elem in str_bytes:
        base = random.randint(0, size - 1)  # Тк мы высиляем рандомизированный хеш, то основание будет всегда случайным
        hash = (hash * base + elem) % size
    return hash


print("Задание №3 - ")
print("\nВведите целое число для вычисление рандомизированной хэш-функции побайтно (желательно неск-ко байт)")
str = input()
print("\nВведите размер желаемого словаря (целое число, желательно простое)")
# В качесте размера словаря выбирают простое число, тк все хеши берутся по его модулю (остаток от деления) и для
# простого числа остатки деления на него будт повторятся реже чем в случае составного и хеши будут уникальными
size = int(input())
print("\nРандомизированный побайтный хеш = ", bytes_universal_hash(str, size))
# Out:
# Задание №3 -
#
# Введите целое число для вычисление рандомизированной хэш-функции побайтно (желательно неск-ко байт)
# 1524654564
#
# Введите размер желаемого словаря (целое число, желательно простое)
# 1000
#
# Рандомизированный побайтный хеш =  447

# %% [markdown]
# # Задание 4

# %%
def gorner_ascii_hash(str, base, size):
    str_bytes = str.encode('ascii')
    hash = 0 # та же схема Горнера
    for elem in str_bytes:
        hash = (hash * base + elem) % size
    return hash


print("Задание №4 - ")
print("\nВведите ascii строку для вычисления ключа методом Горнера")
str = input()
print("\nВведите константное основание (для ascii рекомендуется 127)")
base = int(input())
print("\nВведите размер желаемого словаря (целое число, желательно простое)")
size = int(input())
print("\nХеш ascii строки по методу Горнера = ", gorner_ascii_hash(str, base, size))
# Out:
# Задание №4 -
#
# Введите ascii строку для вычисления ключа методом Горнера
# iophgjrasd
#
# Введите константное основание (для ascii рекомендуется 127)
# 127
#
# Введите размер желаемого словаря (целое число, желательно простое)
# 1000
#
# Хеш ascii строки по методу Горнера =  665
